# %% [markdown]
# # TASK1

# %% [markdown]
# Read the following data set: https://archive.ics.uci.edu/ml/machine-learning-databases/adult/
# Rename the columns as per the description from this file: https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names

# %%
import pandas as pd
adult = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", sep=',', names = ["age", "workclass", "fnlwgt", "education","education_num","marital_status","occupation","relationship","race","sex","capital_gain","capital_loss","hours_per_week","native_country","label"])
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country   label
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# 1.Create a sql db from adult dataset and name it sqladb

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect('sqladb.db')
c=conn.cursor()
c.execute('''CREATE TABLE [sqladb] ([Age] INTEGER, [WorkClass] varchar(40), [Fnlwgt] INTEGER, [Education] varchar(40), [Education_Num] INTEGER, [Marital_status] varchar(40), [Occupation] varchar(20), [Relationship] varchar(40), [Race] varchar(20), [Sex] varchar(10), [Capital_Gain] INTEGER, [Capital_Loss] INTEGER, [Hours_Per_Week] INTEGER, [Native_Country] varchar(50), [Label] varchar(10));''')
sqladb = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", sep=',', names = ["age", "workclass", "fnlwgt", "education","education_num","marital_status","occupation","relationship","race","sex","capital_gain","capital_loss","hours_per_week","native_country","label"])
sqladb.to_sql('adult', conn, if_exists='append', index = False)

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %% [markdown]
# 1.Select 10 records from the adult sqladb

# %%
pysqldf("SELECT * FROM sqladb LIMIT 10")
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital_status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %% [markdown]
# 2.Show me the average hours per week of all men who are working in private sector

# %%
q='''
select hours_per_week from sqladb where workclass = ' Private' and sex=' Male'
'''
pysqldf(q)
# Out:
#        hours_per_week
# 0                  40
# 1                  40
# 2                  40
# 3                  80
# 4                  50
# 5                  40
# 6                  45
# 7                  40
# 8                  50
# 9                  60
# 10                 40
# 11                 40
# 12                 80
# 13                 40
# 14                 44
# 15                 40
# 16                 40
# 17                 40
# 18                 38
# 19                 43
# 20                 50
# 21                 35
# 22                 38
# 23                 43
# 24                 40
# 25                 40
# 26                 40
# 27                 48
# 28                 40
# 29                 40
# ...               ...
# 14914              40
# 14915              40
# 14916              60
# 14917              40
# 14918              40
# 14919              40
# 14920              55
# 14921              40
# 14922              45
# ...

# %% [markdown]
#  3.Show me the frequency table for education, occupation and relationship, separately

# %%
pysqldf("select * from sqladb group by education")
# Out:
#     age          workclass  fnlwgt      education  education_num  \
# 0    32            Private   34066           10th              6
# 1    58            Private  147707           11th              7
# 2    22            Private  325033           12th              8
# 3    23            Private  180771        1st-4th              2
# 4    45            Private  199590        5th-6th              3
# 5    36            Private  131459        7th-8th              4
# 6    71            Private  138145            9th              5
# 7    27            Private  257302     Assoc-acdm             12
# 8    43            Private   84661      Assoc-voc             11
# 9    38            Private  139180      Bachelors             13
# 10   71                  ?  287372      Doctorate             16
# 11   52       Self-emp-inc  287927        HS-grad              9
# 12   53            Private  321865        Masters             14
# ...

# %%
pysqldf("select * from sqladb group by occupation")
# Out:
#     age          workclass  fnlwgt      education  education_num  \
# 0    72                  ?  129912        HS-grad              9
# 1    22            Private  201490        HS-grad              9
# 2    23        Federal-gov  173851        HS-grad              9
# 3    43   Self-emp-not-inc   27242   Some-college             10
# 4    52       Self-emp-inc  287927        HS-grad              9
# 5    61   Self-emp-not-inc   50483        7th-8th              4
# 6    32            Private   34066           10th              6
# 7    40            Private  154374        HS-grad              9
# 8    31            Private  199655        Masters             14
# 9    17            Private  141590           11th              7
# 10   65   Self-emp-not-inc   99359    Prof-school             15
# 11   22            Private  310152   Some-college             10
# 12   43            Private   84661      Assoc-voc             11
# ...

# %%
pysqldf("select * from sqladb group by relationship")
# Out:
#    age      workclass  fnlwgt      education  education_num  \
# 0   40        Private  154374        HS-grad              9
# 1   22        Private  310152   Some-college             10
# 2   43      State-gov  255835   Some-college             10
# 3   22        Private  201490        HS-grad              9
# 4   58        Private  151910        HS-grad              9
# 5   52   Self-emp-inc  287927        HS-grad              9
#
#         marital_status          occupation     relationship    race      sex  \
# 0   Married-civ-spouse   Machine-op-inspct          Husband   White     Male
# 1        Never-married     Protective-serv    Not-in-family   White     Male
# 2             Divorced        Adm-clerical   Other-relative   White   Female
# 3        Never-married        Adm-clerical        Own-child   White     Male
# 4              Widowed        Adm-clerical        Unmarried   White   Female
# 5   Married-civ-spouse     Exec-managerial             Wife   White   Female
#
# ...

# %% [markdown]
# 4.Are there any people who are married, working in private sector and having a masters
# degree

# %%
pysqldf('''
select * from sqladb where workclass = " Private" and education=" Masters" and marital_status=" Married-civ-spouse"
''')
# Out:
#      age workclass  fnlwgt education  education_num       marital_status  \
# 0     37   Private  284582   Masters             14   Married-civ-spouse
# 1     33   Private  202051   Masters             14   Married-civ-spouse
# 2     76   Private  124191   Masters             14   Married-civ-spouse
# 3     31   Private   99928   Masters             14   Married-civ-spouse
# 4     35   Private  138992   Masters             14   Married-civ-spouse
# 5     34   Private  142897   Masters             14   Married-civ-spouse
# 6     62   Private  270092   Masters             14   Married-civ-spouse
# 7     41   Private  445382   Masters             14   Married-civ-spouse
# 8     33   Private  208405   Masters             14   Married-civ-spouse
# 9     49   Private  192776   Masters             14   Married-civ-spouse
# 10    51   Private  410114   Masters             14   Married-civ-spouse
# 11    31   Private  118710   Masters             14   Married-civ-spouse
# ...

# %% [markdown]
# 5.What is the average, minimum and maximum age group for people working in different
# sectors

# %%
pysqldf('''
select workclass, avg(age), min(age), max(age) from sqladb group by workclass;
''')
# Out:
#            workclass   avg(age)  min(age)  max(age)
# 0                  ?  40.960240        17        90
# 1        Federal-gov  42.590625        17        90
# 2          Local-gov  41.751075        17        90
# 3       Never-worked  20.571429        17        30
# 4            Private  36.797585        17        90
# 5       Self-emp-inc  46.017025        17        84
# 6   Self-emp-not-inc  44.969697        17        90
# 7          State-gov  39.436055        17        81
# 8        Without-pay  47.785714        19        72

# %% [markdown]
# 6.Calculate age distribution by country

# %%
pysqldf('''
select
case
when age<25 then 'Under 25'
when age between 25 and 50 then '25-50'
when age between 51 and 99 then '51-99'
end as age_range, count(*) as count,native_country from sqladb group by native_country, age_range
order by native_country desc
''')
# Out:
#     age_range  count       native_country
# 0       25-50     11           Yugoslavia
# 1       51-99      3           Yugoslavia
# 2    Under 25      2           Yugoslavia
# 3       25-50     36              Vietnam
# 4       51-99      8              Vietnam
# 5    Under 25     23              Vietnam
# 6       25-50  18248        United-States
# 7       51-99   5866        United-States
# 8    Under 25   5056        United-States
# 9       25-50     15      Trinadad&Tobago
# 10      51-99      3      Trinadad&Tobago
# 11   Under 25      1      Trinadad&Tobago
# 12      25-50     13             Thailand
# 13      51-99      1             Thailand
# 14   Under 25      4             Thailand
# 15      25-50     40               Taiwan
# 16      51-99      4               Taiwan
# 17   Under 25      7               Taiwan
# 18      25-50     48                South
# 19      51-99     15                South
# 20   Under 25     17                South
# ...

# %%
pysqldf('''
SELECT native_country, COUNT (*) AS age
FROM sqladb
GROUP BY native_country ORDER BY COUNT(*) DESC
''')
# Out:
#                  native_country    age
# 0                 United-States  29170
# 1                        Mexico    643
# 2                             ?    583
# 3                   Philippines    198
# 4                       Germany    137
# 5                        Canada    121
# 6                   Puerto-Rico    114
# 7                   El-Salvador    106
# 8                         India    100
# 9                          Cuba     95
# 10                      England     90
# 11                      Jamaica     81
# 12                        South     80
# 13                        China     75
# 14                        Italy     73
# 15           Dominican-Republic     70
# 16                      Vietnam     67
# 17                    Guatemala     64
# 18                        Japan     62
# 19                       Poland     60
# 20                     Columbia     59
# 21                       Taiwan     51
# 22                        Haiti     44
# ...

# %% [markdown]
# 7.Compute a new column as 'Net-Capital-Gain' from the two columns 'capital-gain' and
# 'capital-loss'

# %%
pysqldf('''
select capital_gain, capital_loss, capital_gain-capital_loss as profit from sqladb;
''')
# Out:
#        capital_gain  capital_loss  profit
# 0              2174             0    2174
# 1                 0             0       0
# 2                 0             0       0
# 3                 0             0       0
# 4                 0             0       0
# 5                 0             0       0
# 6                 0             0       0
# 7                 0             0       0
# 8             14084             0   14084
# 9              5178             0    5178
# 10                0             0       0
# 11                0             0       0
# 12                0             0       0
# 13                0             0       0
# 14                0             0       0
# 15                0             0       0
# 16                0             0       0
# 17                0             0       0
# 18                0             0       0
# 19                0             0       0
# 20                0             0       0
# ...

# %% [markdown]
# # TASK2

# %% [markdown]
# 1.Create an sqlalchemy engine using a sample from the data set

# %%
import pandas as pd
from sqlalchemy import create_engine
adult = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", sep=',', names = ["age", "workclass", "fnlwgt", "education","education_num","marital_status","occupation","relationship","race","sex","capital_gain","capital_loss","hours_per_week","native_country","label"])
engine=create_engine('sqlite:///:memory:')
with engine.connect() as conn,conn.begin():
    adult.to_sql('csv',conn,if_exists='replace',index=False)

# %%
import sqlite3
conn=sqlite3.connect('adult.db')
c=conn.cursor()

# %% [markdown]
# 2.Write two basic update queries

# %%
#Updating value of age to 50 if education is Bachelors
c.execute("UPDATE adult SET age = 50 WHERE education=' Bachelors'")
conn.commit()
c.execute("select * from adult limit 20 ")
[(row[0],row[3]) for row in c.fetchall()]
# Out:
# [(50, ' Bachelors'),
#  (50, ' Bachelors'),
#  (38, ' HS-grad'),
#  (53, ' 11th'),
#  (50, ' Bachelors'),
#  (37, ' Masters'),
#  (49, ' 9th'),
#  (52, ' HS-grad'),
#  (31, ' Masters'),
#  (50, ' Bachelors'),
#  (37, ' Some-college'),
#  (50, ' Bachelors'),
#  (50, ' Bachelors'),
#  (32, ' Assoc-acdm'),
#  (40, ' Assoc-voc'),
#  (34, ' 7th-8th'),
#  (25, ' HS-grad'),
#  (32, ' HS-grad'),
#  (38, ' 11th'),
#  (43, ' Masters')]

# %%
#Updating Male in column sex to 'M'(and Updated value of age to 50 if education is Bachelors)
c.execute("UPDATE adult SET sex ='M' where sex=' Male' ")
conn.commit()
c.execute("select * from adult limit 20 ")
[row[9] for row in c.fetchall()]
# Out:
# ['M',
#  'M',
#  'M',
#  'M',
#  ' Female',
#  ' Female',
#  ' Female',
#  'M',
#  ' Female',
#  'M',
#  'M',
#  'M',
#  ' Female',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  ' Female']

# %% [markdown]
# 3.Write two basic delete queries

# %%
#Delete all records whose gender is Female(Updated value of age to 50 for education=Bachelors and updated value of male to M)
c.execute("DELETE FROM adult where sex=' Female'")
conn.commit()
c.execute("select * from adult limit 20")
data=c.fetchall()
print(data)
# Out:
# [(50, ' State-gov', 77516, ' Bachelors', 13, ' Never-married', ' Adm-clerical', ' Not-in-family', ' White', 'M', 2174, 0, 40, ' United-States', ' <=50K'), (50, ' Self-emp-not-inc', 83311, ' Bachelors', 13, ' Married-civ-spouse', ' Exec-managerial', ' Husband', ' White', 'M', 0, 0, 13, ' United-States', ' <=50K'), (38, ' Private', 215646, ' HS-grad', 9, ' Divorced', ' Handlers-cleaners', ' Not-in-family', ' White', 'M', 0, 0, 40, ' United-States', ' <=50K'), (53, ' Private', 234721, ' 11th', 7, ' Married-civ-spouse', ' Handlers-cleaners', ' Husband', ' Black', 'M', 0, 0, 40, ' United-States', ' <=50K'), (52, ' Self-emp-not-inc', 209642, ' HS-grad', 9, ' Married-civ-spouse', ' Exec-managerial', ' Husband', ' White', 'M', 0, 0, 45, ' United-States', ' >50K'), (50, ' Private', 159449, ' Bachelors', 13, ' Married-civ-spouse', ' Exec-managerial', ' Husband', ' White', 'M', 5178, 0, 40, ' United-States', ' >50K'), (37, ' Private', 280464, ' Some-college', 10, ' Married-civ-spouse', ' Exec-m
# ...

# %%
#Delete all records if education_num less than 13(deleted male records)
c.execute("DELETE FROM adult where education_num < 13")
conn.commit()
c.execute("select * from adult limit 20")
data=c.fetchall()
print(data)
# Out:
# [(50, ' State-gov', 77516, ' Bachelors', 13, ' Never-married', ' Adm-clerical', ' Not-in-family', ' White', 'M', 2174, 0, 40, ' United-States', ' <=50K'), (50, ' Self-emp-not-inc', 83311, ' Bachelors', 13, ' Married-civ-spouse', ' Exec-managerial', ' Husband', ' White', 'M', 0, 0, 13, ' United-States', ' <=50K'), (50, ' Private', 159449, ' Bachelors', 13, ' Married-civ-spouse', ' Exec-managerial', ' Husband', ' White', 'M', 5178, 0, 40, ' United-States', ' >50K'), (50, ' State-gov', 141297, ' Bachelors', 13, ' Married-civ-spouse', ' Prof-specialty', ' Husband', ' Asian-Pac-Islander', 'M', 0, 0, 40, ' India', ' >50K'), (40, ' Private', 193524, ' Doctorate', 16, ' Married-civ-spouse', ' Prof-specialty', ' Husband', ' White', 'M', 0, 0, 60, ' United-States', ' >50K'), (50, ' Local-gov', 216851, ' Bachelors', 13, ' Married-civ-spouse', ' Tech-support', ' Husband', ' White', 'M', 0, 0, 40, ' United-States', ' >50K'), (50, ' Private', 386940, ' Bachelors', 13, ' Divorced', ' Exec-manageria
# ...

# %% [markdown]
# 4.Write two basic filter queries

# %%
#Filter by sex=Male and education_num=13
c.execute("select * from adult where sex='M' and education_num = 13 limit 20")
values=c.fetchall()
print(values)
# Out:
# [(50, ' State-gov', 77516, ' Bachelors', 13, ' Never-married', ' Adm-clerical', ' Not-in-family', ' White', 'M', 2174, 0, 40, ' United-States', ' <=50K'), (50, ' Self-emp-not-inc', 83311, ' Bachelors', 13, ' Married-civ-spouse', ' Exec-managerial', ' Husband', ' White', 'M', 0, 0, 13, ' United-States', ' <=50K'), (50, ' Private', 159449, ' Bachelors', 13, ' Married-civ-spouse', ' Exec-managerial', ' Husband', ' White', 'M', 5178, 0, 40, ' United-States', ' >50K'), (50, ' State-gov', 141297, ' Bachelors', 13, ' Married-civ-spouse', ' Prof-specialty', ' Husband', ' Asian-Pac-Islander', 'M', 0, 0, 40, ' India', ' >50K'), (50, ' Local-gov', 216851, ' Bachelors', 13, ' Married-civ-spouse', ' Tech-support', ' Husband', ' White', 'M', 0, 0, 40, ' United-States', ' >50K'), (50, ' Private', 386940, ' Bachelors', 13, ' Divorced', ' Exec-managerial', ' Own-child', ' White', 'M', 0, 1408, 40, ' United-States', ' <=50K'), (50, ' Self-emp-not-inc', 88506, ' Bachelors', 13, ' Married-civ-spouse', '
# ...

# %%
#Filter only marital_status, workclass and race columns
c.execute("select marital_status,workclass, race from adult limit 20")
#conn.commit()
[row for row in c.fetchall()]
# Out:
# [(' Never-married', ' State-gov', ' White'),
#  (' Married-civ-spouse', ' Self-emp-not-inc', ' White'),
#  (' Married-civ-spouse', ' Private', ' White'),
#  (' Married-civ-spouse', ' State-gov', ' Asian-Pac-Islander'),
#  (' Married-civ-spouse', ' Private', ' White'),
#  (' Married-civ-spouse', ' Local-gov', ' White'),
#  (' Divorced', ' Private', ' White'),
#  (' Married-civ-spouse', ' Self-emp-not-inc', ' White'),
#  (' Married-civ-spouse', ' Private', ' White'),
#  (' Married-civ-spouse', ' Federal-gov', ' Black'),
#  (' Divorced', ' Federal-gov', ' White'),
#  (' Married-civ-spouse', ' Private', ' White'),
#  (' Married-civ-spouse', ' Private', ' White'),
#  (' Married-civ-spouse', ' Self-emp-not-inc', ' White'),
#  (' Married-civ-spouse', ' Private', ' White'),
#  (' Married-civ-spouse', ' Private', ' White'),
#  (' Married-civ-spouse', ' Local-gov', ' White'),
#  (' Married-civ-spouse', ' Self-emp-not-inc', ' White'),
#  (' Married-civ-spouse', ' Private', ' White'),
# ...

# %% [markdown]
# 5.Write two basic function queries

# %%
#Function to find sum of capital_loss(Existing database values)
val=c.execute("select sum(capital_loss) from adult")
values=val.fetchone()
print(values[0])
# Out:
# 924792

# %%
#function to find total number of Whites(Existing database values)
val=c.execute("select count(*) from adult where race=' White'")
values=val.fetchone()
print(values[0])
# Out:
# 5135
